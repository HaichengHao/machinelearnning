# %%
# %%HTML
# <style type='text/css'>
#     *{
#         # background-color:#E3EDCD;
#         # background-color:black;
#         # color:white;
#
#     }
#     h1{
#         color:#1976d2;
#     }
#     h2{
#         color:#f57c00;
#     }
#     h3{
#         color:#ba37ff;
#     }
#     h4{
#         color:green;
#     }
#     table{
#         border:1px solid black !important;
#         border-collapse:collapse !important;
#     }
#     th{
#         background-color:blueviolet !important;
#         text-align:center;
#         color:white;
#     }
#     th,td{
#         border:0.1px solid black !important;
#         transition:0.2s all liner;
#
#     }
#     td:hover{
#         transform:scale(1.1);
#         background-color:orange;
#         color:blueviolet;
#     }
#     .raw{
#         white-space:pre;
#     }
#     .atcenter{
#         text-align:center !important;
#     }
#     .imp{
#         color:red;
#         font-weight:bolder;
#     }
# </style>
# Out:
# <style type='text/css'>
#     *{
#         # background-color:#E3EDCD;
#         # background-color:black;
#         # color:white;
#
#     }
#     h1{
#         color:#1976d2;
#     }
#     h2{
#         color:#f57c00;
#     }
#     h3{
#         color:#ba37ff;
#     }
#     h4{
#         color:green;
#     }
#     table{
#         border:1px solid black !important;
#         border-collapse:collapse !important;
#     }
#     th{
#         background-color:blueviolet !important;
#         text-align:center;
#         color:white;
#     }
#     th,td{
#         border:0.1px solid black !important;
#         transition:0.2s all liner;
#
#     }
#     td:hover{
#         transform:scale(1.1);
#         background-color:orange;
#         color:blueviolet;
#     }
#     .raw{
#         white-space:pre;
#     }
#     .atcenter{
#         text-align:center !important;
#     }
#     .imp{
#         color:red;
#         font-weight:bolder;
#     }
# </style>

# %% [markdown]
# # 使用Faker生成数据

# %%
import pyecharts.options as opts
from pyecharts.globals import CurrentConfig,ThemeType,RenderType,NotebookType
CurrentConfig.NOTEBOOK_TYPE = NotebookType.JUPYTER_LAB
from pyecharts.charts import Bar
from pyecharts.faker import Faker

# %%
c = (
    Bar(
        init_opts=opts.InitOpts(
            page_title='不过是个标题',
            # width=,
            # height=,
                
        )
    )
    .add_xaxis(Faker.choose())
    .add_yaxis('类别A',Faker.values())
    # 设置全局配置项
    .set_global_opts(
        # 设置标题
        title_opts=opts.TitleOpts(
            title='主标题',
            subtitle='副标题',
            # item_gap=,
        ),
        # 设置图例
        legend_opts=opts.LegendOpts(
            type_='scroll',
            orient='virtical',
            pos_right=0,
            pos_top=30,
            legend_icon='circle'
        ),
        # 设置工具箱配置项
        toolbox_opts=opts.ToolboxOpts(),
        # 设置可视化映射
        visualmap_opts=opts.VisualMapOpts(
            range_text=['高','低'],
            # range_color=[],
        ),
        # 设置提示框
        tooltip_opts=opts.TooltipOpts(
            # formatter='{a}:\n{b}{c}',
            background_color='blueviolet',
            textstyle_opts=opts.TextStyleOpts(
                color='white'
            )
        ),
        # 设置数据缩放
        datazoom_opts=opts.DataZoomOpts(
            range_start=20,
            is_zoom_lock=False,
            
        )
    )
    # 设置系列配置项
    .set_series_opts(
        # 设置图例标签文字配置项
        label_opts=opts.LabelOpts(
            position='right',
            rotate=0,
        ),
        # 图元配置项
        itemstyle_opts=opts.ItemStyleOpts(
            border_color='purple',
            border_width=3,
            opacity=0.6
        ),
        # 线条配置项
        linestyle_opts=opts.LineStyleOpts(
            type_='solid',
            # color='orange'
        ),

        # 标记点和标记线配置项
        markpoint_opts=opts.MarkPointOpts(
            data=[
                opts.MarkPointItem(type_='max',symbol='pin'),
                opts.MarkPointItem(type_='min',symbol='pin')
            ]
        ),
        markline_opts=opts.MarkLineOpts(
            data=[
                opts.MarkLineItem(type_='average',name='均值点')
            ],
            label_opts=opts.LabelOpts(
                color='red'
            )
        )
    )
    
)

# %%
c.load_javascript()

# %%
c.render_notebook()
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
# </head>
# <body>
#         <div id="6cd3a57dd596482d975238ad0ca3643f" class="chart-container" style="width:900px; height:500px; "></div>
#     <script>
#         var chart_6cd3a57dd596482d975238ad0ca3643f = echarts.init(
#             document.getElementById('6cd3a57dd596482d975238ad0ca3643f'), 'white', {renderer: 'canvas'});
#         var option_6cd3a57dd596482d975238ad0ca3643f = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
# ...

# %% [markdown]
# # 这节主要介绍的是faker

# %% [markdown]
# ###  运行<span class='imp'>Faker.choose()</span>会产生7个相同属性的名词

# %% [markdown]
# ### 运行Faker.values()会产生7个数值

# %% [markdown]
# ### 运行Faker.cars()会产生7个车名

# %% [markdown]
# ### 运行Faker.country()会产生7个国家的名字

# %% [markdown]
# Faker.visual_color 会产生固定的11个hex格式的颜色,注意这里是属性,不再是方法,不加括号

# %% [markdown]
# Faker.day会产生天数

# %% [markdown]
# Faker.days_values

# %% [markdown]
# Faker.clock 会产生时钟的列表
