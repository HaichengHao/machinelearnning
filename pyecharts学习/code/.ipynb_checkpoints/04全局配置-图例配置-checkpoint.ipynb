# %%
# %%HTML
# <style type='text/css'>
#     *{
#         # background-color:#E3EDCD;
#         # background-color:black;
#         # color:white;
#
#     }
#     h1{
#         color:#1976d2;
#     }
#     h2{
#         color:#f57c00;
#     }
#     h3{
#         color:#ba37ff;
#     }
#     h4{
#         color:green;
#     }
#     table{
#         border:1px solid black !important;
#         border-collapse:collapse !important;
#     }
#     th{
#         background-color:blueviolet !important;
#         text-align:center;
#         color:white;
#     }
#     th,td{
#         border:0.1px solid black !important;
#         transition:0.2s all liner;
#
#     }
#     td:hover{
#         transform:scale(1.1);
#         background-color:orange;
#         color:blueviolet;
#     }
#     .raw{
#         white-space:pre;
#     }
#     .atcenter{
#         text-align:center !important;
#     }
#     .imp{
#         color:red;
#         font-weight:bolder;
#     }
# </style>
# Out:
# <style type='text/css'>
#     *{
#         # background-color:#E3EDCD;
#         # background-color:black;
#         # color:white;
#
#     }
#     h1{
#         color:#1976d2;
#     }
#     h2{
#         color:#f57c00;
#     }
#     h3{
#         color:#ba37ff;
#     }
#     h4{
#         color:green;
#     }
#     table{
#         border:1px solid black !important;
#         border-collapse:collapse !important;
#     }
#     th{
#         background-color:blueviolet !important;
#         text-align:center;
#         color:white;
#     }
#     th,td{
#         border:0.1px solid black !important;
#         transition:0.2s all liner;
#
#     }
#     td:hover{
#         transform:scale(1.1);
#         background-color:orange;
#         color:blueviolet;
#     }
#     .raw{
#         white-space:pre;
#     }
#     .atcenter{
#         text-align:center !important;
#     }
#     .imp{
#         color:red;
#         font-weight:bolder;
#     }
# </style>

# %% [markdown]
# # 图例配置项

# %% [markdown]
# ##  导入需要的包

# %%
from pyecharts.charts import Bar
from pyecharts import options as opts
from pyecharts.globals import CurrentConfig,NotebookType,RenderType,ThemeType
CurrentConfig.NOTEBOOK_TYPE = NotebookType.JUPYTER_LAB
from pyecharts.faker import Faker

# %% [markdown]
# 我们还是用上一节的代码因为这样到最后会有一个整体的认知,而且写的时候按着从上到下，从左至右的顺序来的，非常方便日后记忆

# %%
c=(
    Bar(
        # 设置初始化配置项
        init_opts=opts.InitOpts(
            bg_color='azure',
            page_title='网页标题1',
            # width='500px',
            height='450px',
            theme=ThemeType.ESSOS
        )
    )
    .add_xaxis(Faker.choose())
    .add_yaxis('A类',Faker.values())
    .add_yaxis('B类',Faker.values())
    .add_yaxis('C类',Faker.values())
    .add_yaxis('D类',Faker.values())
    .add_yaxis('E类',Faker.values())
    .add_yaxis('F类',Faker.values())
    .add_yaxis('G类',Faker.values())
    .add_yaxis('H类',Faker.values())
    # 设置全局配置项
    .set_global_opts(
        # 设置标题配置项
        # TitleOptions
        title_opts=opts.TitleOpts(
            title='主标题',
            subtitle='副标题',
            # pos_bottom=0,
            # pos_left=0,
            # padding=10, #注意padding直接写就可以不需要用引号引起来
            # item_gap= 40 #设置主标题和副标题的间距
            # 写法很多,也可以pos_方向='npx'这种形式指定像素
            # 也可以写pos_方向='n%'这样的形式，结合前端知识理解更快更容易
            # 我们也可以写内边距不得不佩服baidu前端大佬写的echarts对与有前端基础的人太友好了
            
        ),
        # 设置图例配置项
        legend_opts=opts.LegendOpts(
            # 图例的类型有两种 ,默认是plain,还有一种是可以滚动scroll,适合图例非常多的情况
            type_="scroll",
            orient='vertical',#控制方向,两个选择,水平或者垂直
            pos_right=0, #像定位这些很多全局配置项目都是通用的
            pos_top=20,
            # is_show=False #是否显示图例,如果是False则会隐藏图例
            # 选择模式
            # 4个值,True为开启图例点击(默认),False为不开启图例点击,这俩不用加引号
            # single：默认单选 multipel:多选 这俩要加引号
            selected_mode='multiple',
            # item_gap= 3 #没错这个和上面的titleopts也是差不多的,不过控制的是图例之间的间距
            align='right', #默认是auto,设置图例的对齐方式,相对于文字而言的色块儿的位置
            item_width=10, #设置图例的宽度 
            item_height=10, #设置图例的高度
            inactive_color='black', #设置图例非激活状态下的颜色默认是灰色
            legend_icon= 'triangle'  #甚至可以改图例的图表样式
            # 常见的图标 'circle','rect','roundRect(圆角矩形，默认选项)','triangle(三角形)','dismond','arrow'
            # 甚至你可以自己指定一个图标的文件路径也行,就像是html中可以指定cursour即鼠标的样式
        ),
        # 设置工具箱配置ToolboxOpts
        toolbox_opts=opts.ToolboxOpts(),

        # 设置书局缩放配置项
        # DatazoomOptions
        datazoom_opts=opts.DataZoomOpts(
            is_show=True, #是否显示底部滑块组件
            # type_='slide', #设置滑块组件样式,默认就是slide还有一个是inside
            # 我们来看一下inside
            # type_='inside'
            is_realtime=True, #是否实时渲染图表默认True
            range_start=20,#设置滑块区域(数据窗口的起始位置)的默认位置,默认是20，我们可以自己指定
            orient='horizontal', #修改水平方向默认是horizontal,如果改成垂直那就是virtical
            # is_zoom_lock=True #是否锁定选择区域,如果锁定那就不能缩放只能平移
        )
    )
)
c.load_javascript()

# %%
c.render_notebook()
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
# </head>
# <body>
#         <div id="15ac74e8322e437bb7d03c91bcb3523e" class="chart-container" style="width:900px; height:450px; "></div>
#     <script>
#         var chart_15ac74e8322e437bb7d03c91bcb3523e = echarts.init(
#             document.getElementById('15ac74e8322e437bb7d03c91bcb3523e'), 'essos', {renderer: 'canvas'});
#         var option_15ac74e8322e437bb7d03c91bcb3523e = {
#     "backgroundColor": "azure",
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "series": [
#         {
#             "type": "bar",
#             "name": "A\u7c7b",
#             "legendHoverLink": true,
#             "data": [
#                 82,
# ...
